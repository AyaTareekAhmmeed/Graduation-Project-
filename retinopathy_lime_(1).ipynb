# %% [markdown]
# <a href="https://colab.research.google.com/github/AyaTareekAhmmeed/Graduation-Project-/blob/main/retinopathy_lime_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
model = keras.models.load_model('/content/eye_disease_model (5).h5')

# %%
# !pip install lime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 KB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283859 sha256=7f41dc5d9ba4014c981b1a749f1f58f28e63601e506fe286ae3fdc7c1c91440e
#   Stored in directory: /root/.cache/pip/wheels/ed/d7/c9/5a0130d06d6310bc6cbe55220e6e72dcb8c4eff9a478717066
# Successfully built lime
# ...

# %%
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries
import matplotlib.pyplot as plt
import random

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt


def predict_class(path):
    img = cv2.imread(path)

    RGBImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    RGBImg= cv2.resize(RGBImg,(224,224))
    plt.imshow(RGBImg)
    image = np.array(RGBImg) / 255.0
    new_model = tf.keras.models.load_model("/content/eye_disease_model (5).h5")
    predict=new_model.predict(np.array([image]))
    per=np.argmax(predict,axis=1)
    if per==1:
        print('No DR')
    else:
        print('DR')

# %%
predict_class('/content/05cd0178ccfe.png')
# Out:
# 1/1 [==============================] - 0s 126ms/step
# DR

# %%
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread('/content/05cd0178ccfe.png')
#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 29ms/step

# %%
predict_class('/content/0124dffecf29.png')
# Out:
# 1/1 [==============================] - 0s 123ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/0124dffecf29.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step

# %%
predict_class('/content/034cb07a550f.png')
# Out:
# 1/1 [==============================] - 0s 124ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/034cb07a550f.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 38ms/step

# %%
predict_class('/content/01eb826f6467.png')
# Out:
# 1/1 [==============================] - 0s 195ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/01eb826f6467.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 29ms/step

# %%
predict_class('/content/07122e268a1d.png')
# Out:
# 1/1 [==============================] - 0s 261ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/07122e268a1d.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step

# %%
predict_class('/content/24b87f744598.png')
# Out:
# 1/1 [==============================] - 0s 122ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/24b87f744598.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 30ms/step

# %%
predict_class('/content/299086c6d1b5.png')
# Out:
# 1/1 [==============================] - 0s 207ms/step
# DR

# %%
# Read Images
img = mpimg.imread('/content/299086c6d1b5.png')

#DR
explainer = lime_image.LimeImageExplainer(random_state=42)
explanation = explainer.explain_instance(
         img, 
         model.predict
)
plt.imshow(img)
image, mask = explanation.get_image_and_mask(
         model.predict(
              img.reshape((1,224,224,3))
         ).argmax(axis=1)[0],
         positive_only=True, 
         hide_rest=False)
plt.imshow(mark_boundaries(image, mask))
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step
